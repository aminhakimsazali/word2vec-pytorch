# %%
from datasets import load_dataset

# code : ms
# language: Malay
# size : 7.1M

dataset = load_dataset("oscar-corpus/OSCAR-2301",
                        use_auth_token="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", # required
                        language="ms", 
                        data_dir = ""
#                         streaming=True, # optional
#                         split="train"
                      ) # optional, but the dataset only has a train split
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 7
#       1 from datasets import load_dataset
#       3 # code : ms
#       4 # language: Malay
#       5 # size : 7.1M
# ----> 7 dataset = load_dataset("oscar-corpus/OSCAR-2301",
#       8                         use_auth_token="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", # required
#       9                         language="ms",
#      10
#      11 #                         streaming=True, # optional
#      12 #                         split="train"
#      13                       )
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\load.py:1759, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, num_proc, **config_kwargs)
#    1754 verification_mode = VerificationMode(
#    1755     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1756 )
#    1758 # Create a dataset builder
# -> 1759 builder_instance = load_dataset_builder(
#    1760     path=path,
#    1761     name=name,
#    1762     data_dir=data_dir,
#    1763     data_files=data_files,
#    1764     cache_dir=cache_dir,
#    1765     features=features,
#    1766     download_config=download_config,
#    1767     download_mode=download_mode,
#    1768     revision=revision,
#    1769     use_auth_token=use_auth_token,
#    1770     **config_kwargs,
#    1771 )
#    1773 # Return iterable dataset in case of streaming
#    1774 if streaming:
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\load.py:1522, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, use_auth_token, **config_kwargs)
#    1519     raise ValueError(error_msg)
#    1521 # Instantiate the dataset builder
# -> 1522 builder_instance: DatasetBuilder = builder_cls(
#    1523     cache_dir=cache_dir,
#    1524     config_name=config_name,
#    1525     data_dir=data_dir,
#    1526     data_files=data_files,
#    1527     hash=hash,
#    1528     features=features,
#    1529     use_auth_token=use_auth_token,
#    1530     **builder_kwargs,
#    1531     **config_kwargs,
#    1532 )
#    1534 return builder_instance
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\builder.py:319, in DatasetBuilder.__init__(self, cache_dir, config_name, hash, base_path, info, features, use_auth_token, repo_id, data_files, data_dir, name, **config_kwargs)
#     317 if data_dir is not None:
#     318     config_kwargs["data_dir"] = data_dir
# --> 319 self.config, self.config_id = self._create_builder_config(
#     320     config_name=config_name,
#     321     custom_features=features,
#     322     **config_kwargs,
#     323 )
#     325 # prepare info: DatasetInfo are a standardized dataclass across all datasets
#     326 # Prefill datasetinfo
#     327 if info is None:
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\builder.py:472, in DatasetBuilder._create_builder_config(self, config_name, custom_features, **config_kwargs)
#     470     if "version" not in config_kwargs and hasattr(self, "VERSION") and self.VERSION:
#     471         config_kwargs["version"] = self.VERSION
# --> 472     builder_config = self.BUILDER_CONFIG_CLASS(**config_kwargs)
#     474 # otherwise use the config_kwargs to overwrite the attributes
#     475 else:
#     476     builder_config = copy.deepcopy(builder_config)
#
# TypeError: __init__() got an unexpected keyword argument 'language'

# %%
dataset['train']

# %%
sample = dataset['train'].take(200)

# %%
sample

# %%
list(sample)[60]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 list(sample)[60]
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\iterable_dataset.py:937, in IterableDataset.__iter__(self)
#     934         yield from self._iter_pytorch(ex_iterable)
#     935         return
# --> 937 for key, example in ex_iterable:
#     938     if self.features:
#     939         # `IterableDataset` automatically fills missing columns with None.
#     940         # This is done with `_apply_feature_types_on_example`.
#     941         yield _apply_feature_types_on_example(
#     942             example, self.features, token_per_repo_id=self._token_per_repo_id
#     943         )
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\iterable_dataset.py:678, in TakeExamplesIterable.__iter__(self)
#     677 def __iter__(self):
# --> 678     yield from islice(self.ex_iterable, self.n)
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\iterable_dataset.py:113, in ExamplesIterable.__iter__(self)
#     112 def __iter__(self):
# --> 113     yield from self.generate_examples_fn(**self.kwargs)
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\iterable_dataset.py:763, in _generate_examples_from_tables_wrapper.<locals>.wrapper(**kwargs)
#     761 def wrapper(**kwargs):
#     762     python_formatter = PythonFormatter()
# --> 763     for key, table in generate_tables_fn(**kwargs):
#     764         batch = python_formatter.format_batch(table)
#     765         for i, example in enumerate(_batch_to_examples(batch)):
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\packaged_modules\json\json.py:95, in Json._generate_tables(self, files)
#      94 def _generate_tables(self, files):
# ---> 95     for file_idx, file in enumerate(itertools.chain.from_iterable(files)):
#      96         # If the file is one json object and if we need to look at the list of items in one specific field
#      97         if self.config.field is not None:
#      98             with open(file, encoding="utf-8") as f:
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\download\streaming_download_manager.py:853, in _IterableFromGenerator.__iter__(self)
#     852 def __iter__(self):
# --> 853     yield from self.generator(*self.args, **self.kwargs)
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\download\streaming_download_manager.py:929, in FilesIterable._iter_from_urlpaths(cls, urlpaths, use_auth_token)
#     927     urlpaths = [urlpaths]
#     928 for urlpath in urlpaths:
# --> 929     if xisfile(urlpath, use_auth_token=use_auth_token):
#     930         if xbasename(urlpath).startswith((".", "__")):
#     931             # skipping hidden files
#     932             return
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\download\streaming_download_manager.py:278, in xisfile(path, use_auth_token)
#     276 else:
#     277     storage_options = None
# --> 278 fs, *_ = fsspec.get_fs_token_paths(path, storage_options=storage_options)
#     279 return fs.isfile(main_hop)
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\core.py:586, in get_fs_token_paths(urlpath, mode, num, name_function, storage_options, protocol, expand)
#     584     inkwargs["fo"] = urls
#     585 paths, protocol, _ = chain[0]
# --> 586 fs = filesystem(protocol, **inkwargs)
#     587 if isinstance(urlpath, (list, tuple, set)):
#     588     pchains = [
#     589         _un_chain(stringify_path(u), storage_options or {})[0] for u in urlpath
#     590     ]
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\registry.py:253, in filesystem(protocol, **storage_options)
#     246     warnings.warn(
#     247         "The 'arrow_hdfs' protocol has been deprecated and will be "
#     248         "removed in the future. Specify it as 'hdfs'.",
#     249         DeprecationWarning,
#     250     )
#     252 cls = get_filesystem_class(protocol)
# --> 253 return cls(**storage_options)
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\spec.py:76, in _Cached.__call__(cls, *args, **kwargs)
#      74     return cls._cache[token]
#      75 else:
# ---> 76     obj = super().__call__(*args, **kwargs)
#      77     # Setting _fs_token here causes some static linters to complain.
#      78     obj._fs_token_ = token
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\filesystems\compression.py:134, in ZstdFileSystem.__init__(self, fo, mode, target_protocol, target_options, block_size, **kwargs)
#     125 def __init__(
#     126     self,
#     127     fo: str,
#    (...)
#     132     **kwargs,
#     133 ):
# --> 134     super().__init__(
#     135         fo=fo,
#     136         mode=mode,
#     137         target_protocol=target_protocol,
#     138         target_options=target_options,
#     139         block_size=block_size,
#     140         **kwargs,
#     141     )
#     142     # We need to wrap the zstd decompressor to avoid this error in fsspec==2021.7.0 and zstandard==0.15.2:
#     143     #
#     144     # File "/Users/user/.virtualenvs/hf-datasets/lib/python3.7/site-packages/fsspec/core.py", line 145, in open
#    (...)
#     147     #
#     148     # see https://github.com/intake/filesystem_spec/issues/725
#     149     _enter = self.file.__enter__
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\filesystems\compression.py:37, in BaseCompressedFileFileSystem.__init__(self, fo, target_protocol, target_options, **kwargs)
#      35 super().__init__(self, **kwargs)
#      36 # always open as "rb" since fsspec can then use the TextIOWrapper to make it work for "r" mode
# ---> 37 self.file = fsspec.open(
#      38     fo,
#      39     mode="rb",
#      40     protocol=target_protocol,
#      41     compression=self.compression,
#      42     client_kwargs={"requote_redirect_url": False},  # see https://github.com/huggingface/datasets/pull/5459
#      43     **(target_options or {}),
#      44 )
#      45 self.compressed_name = os.path.basename(self.file.path.split("::")[0])
#      46 self.uncompressed_name = (
#      47     self.compressed_name[: self.compressed_name.rindex(".")]
#      48     if "." in self.compressed_name
#      49     else self.compressed_name
#      50 )
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\core.py:419, in open(urlpath, mode, compression, encoding, errors, protocol, newline, **kwargs)
#     369 def open(
#     370     urlpath,
#     371     mode="rb",
#    (...)
#     377     **kwargs,
#     378 ):
#     379     """Given a path or paths, return one ``OpenFile`` object.
#     380
#     381     Parameters
#    (...)
#     417     ``OpenFile`` object.
#     418     """
# --> 419     return open_files(
#     420         urlpath=[urlpath],
#     421         mode=mode,
#     422         compression=compression,
#     423         encoding=encoding,
#     424         errors=errors,
#     425         protocol=protocol,
#     426         newline=newline,
#     427         expand=False,
#     428         **kwargs,
#     429     )[0]
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\core.py:285, in open_files(urlpath, mode, compression, encoding, errors, name_function, num, protocol, newline, auto_mkdir, expand, **kwargs)
#     282     parents = {fs._parent(path) for path in paths}
#     283     [fs.makedirs(parent, exist_ok=True) for parent in parents]
#     284 return OpenFiles(
# --> 285     [
#     286         OpenFile(
#     287             fs,
#     288             path,
#     289             mode=mode,
#     290             compression=compression,
#     291             encoding=encoding,
#     292             errors=errors,
#     293             newline=newline,
#     294         )
#     295         for path in paths
#     296     ],
#     297     mode=mode,
#     298     fs=fs,
#     299 )
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\core.py:286, in <listcomp>(.0)
#     282     parents = {fs._parent(path) for path in paths}
#     283     [fs.makedirs(parent, exist_ok=True) for parent in parents]
#     284 return OpenFiles(
#     285     [
# --> 286         OpenFile(
#     287             fs,
#     288             path,
#     289             mode=mode,
#     290             compression=compression,
#     291             encoding=encoding,
#     292             errors=errors,
#     293             newline=newline,
#     294         )
#     295         for path in paths
#     296     ],
#     297     mode=mode,
#     298     fs=fs,
#     299 )
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\core.py:76, in OpenFile.__init__(self, fs, path, mode, compression, encoding, errors, newline)
#      74 self.path = path
#      75 self.mode = mode
# ---> 76 self.compression = get_compression(path, compression)
#      77 self.encoding = encoding
#      78 self.errors = errors
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\core.py:465, in get_compression(urlpath, compression)
#     463     compression = infer_compression(urlpath)
#     464 if compression is not None and compression not in compr:
# --> 465     raise ValueError("Compression type %s not supported" % compression)
#     466 return compression
#
# ValueError: Compression type zstd not supported

# %%
import pandas as pd

# %%
data_list = []
for index, each in enumerate(dataset['train']):
    if index > 4:
        break
    text = each['text']
    date = None
    if 'headers' in each['meta'].keys():
        if 'warc-date' in each['meta']['headers'].keys():
            date = each['meta']['headers']['warc-date']
    
    data_list.append([text, date])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 data_list = []
# ----> 2 for index, each in enumerate(dataset['train']):
#       3     if index > 4:
#       4         break
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\iterable_dataset.py:937, in IterableDataset.__iter__(self)
#     934         yield from self._iter_pytorch(ex_iterable)
#     935         return
# --> 937 for key, example in ex_iterable:
#     938     if self.features:
#     939         # `IterableDataset` automatically fills missing columns with None.
#     940         # This is done with `_apply_feature_types_on_example`.
#     941         yield _apply_feature_types_on_example(
#     942             example, self.features, token_per_repo_id=self._token_per_repo_id
#     943         )
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\iterable_dataset.py:113, in ExamplesIterable.__iter__(self)
#     112 def __iter__(self):
# --> 113     yield from self.generate_examples_fn(**self.kwargs)
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\iterable_dataset.py:763, in _generate_examples_from_tables_wrapper.<locals>.wrapper(**kwargs)
#     761 def wrapper(**kwargs):
#     762     python_formatter = PythonFormatter()
# --> 763     for key, table in generate_tables_fn(**kwargs):
#     764         batch = python_formatter.format_batch(table)
#     765         for i, example in enumerate(_batch_to_examples(batch)):
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\packaged_modules\json\json.py:95, in Json._generate_tables(self, files)
#      94 def _generate_tables(self, files):
# ---> 95     for file_idx, file in enumerate(itertools.chain.from_iterable(files)):
#      96         # If the file is one json object and if we need to look at the list of items in one specific field
#      97         if self.config.field is not None:
#      98             with open(file, encoding="utf-8") as f:
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\download\streaming_download_manager.py:853, in _IterableFromGenerator.__iter__(self)
#     852 def __iter__(self):
# --> 853     yield from self.generator(*self.args, **self.kwargs)
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\download\streaming_download_manager.py:929, in FilesIterable._iter_from_urlpaths(cls, urlpaths, use_auth_token)
#     927     urlpaths = [urlpaths]
#     928 for urlpath in urlpaths:
# --> 929     if xisfile(urlpath, use_auth_token=use_auth_token):
#     930         if xbasename(urlpath).startswith((".", "__")):
#     931             # skipping hidden files
#     932             return
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\download\streaming_download_manager.py:278, in xisfile(path, use_auth_token)
#     276 else:
#     277     storage_options = None
# --> 278 fs, *_ = fsspec.get_fs_token_paths(path, storage_options=storage_options)
#     279 return fs.isfile(main_hop)
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\core.py:586, in get_fs_token_paths(urlpath, mode, num, name_function, storage_options, protocol, expand)
#     584     inkwargs["fo"] = urls
#     585 paths, protocol, _ = chain[0]
# --> 586 fs = filesystem(protocol, **inkwargs)
#     587 if isinstance(urlpath, (list, tuple, set)):
#     588     pchains = [
#     589         _un_chain(stringify_path(u), storage_options or {})[0] for u in urlpath
#     590     ]
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\registry.py:253, in filesystem(protocol, **storage_options)
#     246     warnings.warn(
#     247         "The 'arrow_hdfs' protocol has been deprecated and will be "
#     248         "removed in the future. Specify it as 'hdfs'.",
#     249         DeprecationWarning,
#     250     )
#     252 cls = get_filesystem_class(protocol)
# --> 253 return cls(**storage_options)
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\spec.py:76, in _Cached.__call__(cls, *args, **kwargs)
#      74     return cls._cache[token]
#      75 else:
# ---> 76     obj = super().__call__(*args, **kwargs)
#      77     # Setting _fs_token here causes some static linters to complain.
#      78     obj._fs_token_ = token
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\filesystems\compression.py:134, in ZstdFileSystem.__init__(self, fo, mode, target_protocol, target_options, block_size, **kwargs)
#     125 def __init__(
#     126     self,
#     127     fo: str,
#    (...)
#     132     **kwargs,
#     133 ):
# --> 134     super().__init__(
#     135         fo=fo,
#     136         mode=mode,
#     137         target_protocol=target_protocol,
#     138         target_options=target_options,
#     139         block_size=block_size,
#     140         **kwargs,
#     141     )
#     142     # We need to wrap the zstd decompressor to avoid this error in fsspec==2021.7.0 and zstandard==0.15.2:
#     143     #
#     144     # File "/Users/user/.virtualenvs/hf-datasets/lib/python3.7/site-packages/fsspec/core.py", line 145, in open
#    (...)
#     147     #
#     148     # see https://github.com/intake/filesystem_spec/issues/725
#     149     _enter = self.file.__enter__
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\filesystems\compression.py:37, in BaseCompressedFileFileSystem.__init__(self, fo, target_protocol, target_options, **kwargs)
#      35 super().__init__(self, **kwargs)
#      36 # always open as "rb" since fsspec can then use the TextIOWrapper to make it work for "r" mode
# ---> 37 self.file = fsspec.open(
#      38     fo,
#      39     mode="rb",
#      40     protocol=target_protocol,
#      41     compression=self.compression,
#      42     client_kwargs={"requote_redirect_url": False},  # see https://github.com/huggingface/datasets/pull/5459
#      43     **(target_options or {}),
#      44 )
#      45 self.compressed_name = os.path.basename(self.file.path.split("::")[0])
#      46 self.uncompressed_name = (
#      47     self.compressed_name[: self.compressed_name.rindex(".")]
#      48     if "." in self.compressed_name
#      49     else self.compressed_name
#      50 )
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\core.py:419, in open(urlpath, mode, compression, encoding, errors, protocol, newline, **kwargs)
#     369 def open(
#     370     urlpath,
#     371     mode="rb",
#    (...)
#     377     **kwargs,
#     378 ):
#     379     """Given a path or paths, return one ``OpenFile`` object.
#     380
#     381     Parameters
#    (...)
#     417     ``OpenFile`` object.
#     418     """
# --> 419     return open_files(
#     420         urlpath=[urlpath],
#     421         mode=mode,
#     422         compression=compression,
#     423         encoding=encoding,
#     424         errors=errors,
#     425         protocol=protocol,
#     426         newline=newline,
#     427         expand=False,
#     428         **kwargs,
#     429     )[0]
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\core.py:285, in open_files(urlpath, mode, compression, encoding, errors, name_function, num, protocol, newline, auto_mkdir, expand, **kwargs)
#     282     parents = {fs._parent(path) for path in paths}
#     283     [fs.makedirs(parent, exist_ok=True) for parent in parents]
#     284 return OpenFiles(
# --> 285     [
#     286         OpenFile(
#     287             fs,
#     288             path,
#     289             mode=mode,
#     290             compression=compression,
#     291             encoding=encoding,
#     292             errors=errors,
#     293             newline=newline,
#     294         )
#     295         for path in paths
#     296     ],
#     297     mode=mode,
#     298     fs=fs,
#     299 )
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\core.py:286, in <listcomp>(.0)
#     282     parents = {fs._parent(path) for path in paths}
#     283     [fs.makedirs(parent, exist_ok=True) for parent in parents]
#     284 return OpenFiles(
#     285     [
# --> 286         OpenFile(
#     287             fs,
#     288             path,
#     289             mode=mode,
#     290             compression=compression,
#     291             encoding=encoding,
#     292             errors=errors,
#     293             newline=newline,
#     294         )
#     295         for path in paths
#     296     ],
#     297     mode=mode,
#     298     fs=fs,
#     299 )
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\core.py:76, in OpenFile.__init__(self, fs, path, mode, compression, encoding, errors, newline)
#      74 self.path = path
#      75 self.mode = mode
# ---> 76 self.compression = get_compression(path, compression)
#      77 self.encoding = encoding
#      78 self.errors = errors
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\fsspec\core.py:465, in get_compression(urlpath, compression)
#     463     compression = infer_compression(urlpath)
#     464 if compression is not None and compression not in compr:
# --> 465     raise ValueError("Compression type %s not supported" % compression)
#     466 return compression
#
# ValueError: Compression type zstd not supported

# %%
df = pd.DataFrame(data_list)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205592 entries, 0 to 205591
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       205592 non-null  object
#  1   1       205592 non-null  object
# dtypes: object(2)
# memory usage: 3.1+ MB

# %%
df.to_csv("data/OSCAR 2109.xlsx")
