# %% [markdown]
# ## OSCAR-2201
#
#  ['af', 'als', 'am', 'an', 'ar', 'arz', 'as', 'ast', 'av', 'az', 'azb', 'ba', 'be', 'bg', 'bh', 'bn', 'bo', 'bpy', 'br', 'bs', 'bxr', 'ca', 'ce', 'ceb', 'ckb', 'cs', 'cv', 'cy', 'da', 'de', 'diq', 'dsb', 'dv', 'el', 'eml', 'en', 'eo', 'es', 'et', 'eu', 'fa', 'fi', 'fr', 'fy', 'ga', 'gd', 'gl', 'gn', 'gom', 'gu', 'he', 'hi', 'hr', 'hsb', 'hu', 'hy', 'ia', 'id', 'ilo', 'io', 'is', 'it', 'ja', 'jbo', 'jv', 'ka', 'kk', 'km', 'kn', 'ko', 'krc', 'ku', 'kv', 'kw', 'ky', 'la', 'lb', 'lez', 'li', 'lmo', 'lo', 'lt', 'lv', 'mai', 'mg', 'mhr', 'min', 'mk', 'ml', 'mn', 'mr', 'mrj', 'ms', 'mt', 'multi', 'my', 'mzn', 'nah', 'nds', 'ne', 'new', 'nl', 'nn', 'no', 'oc', 'or', 'os', 'pa', 'pl', 'pms', 'pnb', 'ps', 'pt', 'qu', 'ro', 'ru', 'sa', 'sah', 'scn', 'sd', 'sh', 'si', 'sk', 'sl', 'so', 'sq', 'sr', 'su', 'sv', 'sw', 'ta', 'te', 'tg', 'th', 'tk', 'tl', 'tr', 'tt', 'ug', 'uk', 'ur', 'uz', 'vi', 'vo', 'wa', 'war', 'wuu', 'xal', 'xmf', 'yi', 'yo', 'zh']

# %%
from datasets import load_dataset

# Size: 5.3 MB
# Docs: 5,228 
# Words: 217,818

dataset = load_dataset("oscar-corpus/OSCAR-2201",
                        use_auth_token="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", # required
                        language="ms", 
                        
                        streaming=True, # optional
#                         split="train"
                      ) # optional, but the dataset only has a train split

# %%
from datasets import load_dataset

# Size: 7.1 MB
# Docs: 5,228 
# Words: 217,818
dataset2 = load_dataset("oscar-corpus/OSCAR-2301",
                        use_auth_token="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", # required
                        language="ms", 
                        
                        streaming=True, # optional
#                         split="train"
                       ) # optional, but the dataset only has a train split
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[70], line 3
#       1 from datasets import load_dataset
# ----> 3 dataset2 = load_dataset("oscar-corpus/OSCAR-2301",
#       4                         use_auth_token="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", # required
#       5                         language="ms",
#       6
#       7                         streaming=True, # optional
#       8 #                         split="train"
#       9                        )
#
# File ~\anaconda3\envs\pytorch1.13\lib\site-packages\datasets\load.py:1759, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, num_proc, **config_kwargs)
#    1754 verification_mode = VerificationMode(
# ...

# %%
sample = dataset.take(200)

# %%
list(sample)[60]

# %%
import pandas as pd

# %%
df = pd.DataFrame(sample)

# %%
 df['meta'].apply(lambda x : x["line_identifications"][0])
# Out:
# 0       {'label': 'ms', 'prob': 0.8212924}
# 1      {'label': 'ms', 'prob': 0.80138534}
# 2       {'label': 'ms', 'prob': 0.8328557}
# 3       {'label': 'ms', 'prob': 0.9114235}
# 4      {'label': 'ms', 'prob': 0.84252614}
#                       ...
# 195     {'label': 'ms', 'prob': 0.9114235}
# 196     {'label': 'ms', 'prob': 0.9114235}
# 197     {'label': 'ms', 'prob': 0.8179641}
# 198     {'label': 'ms', 'prob': 0.8281295}
# 199     {'label': 'ms', 'prob': 0.9114235}
# Name: meta, Length: 200, dtype: object

# %%
df["labels"] = df['meta'].apply(lambda x : x["line_identifications"][0])

# %%
for index, row in df.iterrows():
    print(index)
    if row['meta'] is not None:
        print(f"{index} Pass")
        if row['meta']["line_identifications"] is not None:
            print(f"{index} Pass 2nd")
            lang_label = row['meta']["line_identifications"]
            print(lang_label)
# Out:
# 0
# 0 Pass
# 0 Pass 2nd
# [{'label': 'ms', 'prob': 0.8212924}]
# 1
# 1 Pass
# 1 Pass 2nd
# [{'label': 'ms', 'prob': 0.80138534}]
# 2
# 2 Pass
# 2 Pass 2nd
# [{'label': 'ms', 'prob': 0.8328557}]
# 3
# 3 Pass
# 3 Pass 2nd
# [{'label': 'ms', 'prob': 0.9114235}]
# 4
# 4 Pass
# 4 Pass 2nd
# [{'label': 'ms', 'prob': 0.84252614}]
# 5
# 5 Pass
# 5 Pass 2nd
# [{'label': 'ms', 'prob': 0.8840943}]
# 6
# 6 Pass
# 6 Pass 2nd
# [{'label': 'ms', 'prob': 0.91945004}]
# 7
# 7 Pass
# 7 Pass 2nd
# [{'label': 'ms', 'prob': 0.9114235}]
# 8
# 8 Pass
# 8 Pass 2nd
# [{'label': 'ms', 'prob': 0.88592935}]
# 9
# 9 Pass
# 9 Pass 2nd
# [{'label': 'ms', 'prob': 0.8857169}]
# 10
# 10 Pass
# 10 Pass 2nd
# [{'label': 'ms', 'prob': 0.8700978}]
# 11
# 11 Pass
# 11 Pass 2nd
# [{'label': 'ms', 'prob': 0.9114235}]
# 12
# 12 Pass
# 12 Pass 2nd
# [{'label': 'ms', 'prob': 0.9170686}]
# 13
# 13 Pass
# 13 Pass 2nd
# [{'label': 'ms', 'prob': 0.84134895}]
# 14
# 14 Pass
# 14 Pass 2nd
# [{'label': 'ms', 'prob': 0.87758946}]
# ...

# %% [markdown]
# ## Wikipedia

# %%
import wikipedia
p = wikipedia.page("Batik")
print(p.url)
print(p.title)
content = p.content # Content of page.
# Out:
# https://en.wikipedia.org/wiki/Laksoy
# Laksoy

# %%
wikipedia.page()
# Out:
# 'Laksoy (also spelled lacsoy), is a traditional Filipino distilled nipa palm liquor. It is derived from tubâ (palm toddy) made from nipa palm sap that has been aged for at least 48 hours. It originates from Eastern Mindanao, the Visayas Islands (where it is known as dalisay or dalisay de nipa), and the Bicol Region (where it is known as barik). During the Spanish colonial period, it was also known as vino de nipa in Spanish. Like the lambanog (made from coconut sap), it is particularly potent, having a typical alcohol content of 70 to 100 proof (40 to 45% abv) after a single distillation.\n\n\n== History ==\n\nTubâ, a kind of palm wine, existed in the Philippines before colonisation. They were widely consumed for recreation and played an important role in various religious rituals. Heavy consumption of alcohol in the Philippine islands was described in several Spanish accounts. Social drinking (tagayan or inuman in Tagalog and Visayan languages) was and continues to be an important a
# ...

# %%
# Import packages
from urllib.request import urlopen
from bs4 import BeautifulSoup
# Specify url of the web page
source = urlopen('https://ms.wikipedia.org/wiki/Betik').read()
# Make a soup 
soup = BeautifulSoup(source,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled" dir="ltr" lang="ms">
# <head>
# <meta charset="utf-8"/>
# <title>Betik - Wikipedia Bahasa Melayu, ensiklopedia bebas</title>
# ...

# %%
# Extract the plain text content from paragraphs
text = ''
for paragraph in soup.find_all('p'):
    text += paragraph.text
    
text
# Out:
# '\nBetik, katis, ketela, ketelah, ketalah, pepaya atau kepaya (nama botani: Carica papaya)[3][4] merupakan spesies tumbuhan dalam genus Carica keluarga Caricaceae.[5] Tumbuhan ini berasal dari Mexico Selatan dan Amerika Tengah,[6][7] namun kini pokoknya ditanam di hampir semua negara beriklim tropika[7] termasuk di Asia Tenggara.\nPokok betik menghasilkan buah yang boleh dimakan. Buah betik banyak dijual di pasar-pasar, termasuk pasar tani, dan pasar sayur. Pucuk, daun muda dan bunga betik sering dicelur untuk dijadikan ulam dan dimakan bersama sambal belacan.[4] Pucuk muda betik berasa pahit, manakala buah muda betik jika dibuat halwa berasa masam-masam manis.\nPerkataan betik (Jawi: \u200f\u200fبتيق\u200e\u200e\u200ecode: ms is deprecated \u200e) dijejak kepada kata bahasa Portugis pateca.[8] Perkataan itu diberikan orang Portugis barangkali selepas mendengarkan perkataan Arab: بِطّيخcode: ar is deprecated  biṭṭīkh yang asalnya bermaksud "tembikai"[9] daripada pedagang-pedagang Ara
# ...
